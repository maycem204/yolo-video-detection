# %%
# !python -m pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (1.2.1)
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
print("API key loaded:", api_key is not None)
# Out:
# API key loaded: True

# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("ROBOFLOW_API_KEY")

# %%
# !python -m pip install ultralytics
# !python -m pip install roboflow
# Out:
# Requirement already satisfied: ultralytics in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (8.4.9)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ultralytics) (2.4.0)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ultralytics) (4.13.0.90)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ultralytics) (12.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ultralytics) (2.10.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ultralytics) (0.25.0)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ultralytics) (1.37.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.37.1 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from polars>=0.20.0->ultralytics) (1.37.1)
# Requirement already satisfied: six>=1.5 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from torch>=1.8.0->ultralytics) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from torch>=1.8.0->ultralytics) (2026.1.0)
# Requirement already satisfied: setuptools in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from torch>=1.8.0->ultralytics) (80.10.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting roboflow
#   Downloading roboflow-1.2.13-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from roboflow) (2026.1.4)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from roboflow) (3.10.8)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from roboflow) (2.4.0)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from roboflow) (12.1.0)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.5-cp314-cp314-win_amd64.whl.metadata (2.3 kB)
# Requirement already satisfied: python-dateutil in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: requests in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from roboflow) (2.32.5)
# Requirement already satisfied: six in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from roboflow) (2.6.3)
# Collecting tqdm>=4.41.0 (from roboflow)
#   Downloading tqdm-4.67.2-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from roboflow) (6.0.3)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.2.0-cp314-cp314-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: colorama in c:\users\eya_k\appdata\roaming\python\python314\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib->roboflow) (4.61.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib->roboflow) (3.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\eya_k\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->roboflow) (3.4.4)
# Downloading roboflow-1.2.13-py3-none-any.whl (91 kB)
# Downloading idna-3.7-py3-none-any.whl (66 kB)
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.8 MB ? eta -:--:--
#     --------------------------------------- 0.8/38.8 MB 2.8 MB/s eta 0:00:14
#    - -------------------------------------- 1.6/38.8 MB 2.8 MB/s eta 0:00:14
#    -- ------------------------------------- 2.4/38.8 MB 3.0 MB/s eta 0:00:13
#    -- ------------------------------------- 2.9/38.8 MB 3.0 MB/s eta 0:00:12
#    --- ------------------------------------ 3.7/38.8 MB 3.2 MB/s eta 0:00:12
#    ---- ----------------------------------- 4.5/38.8 MB 3.3 MB/s eta 0:00:11
#    ----- ---------------------------------- 5.5/38.8 MB 3.5 MB/s eta 0:00:10
#    ------ --------------------------------- 6.3/38.8 MB 3.6 MB/s eta 0:00:10
#    ------- -------------------------------- 7.3/38.8 MB 3.7 MB/s eta 0:00:09
#    -------- ------------------------------- 8.4/38.8 MB 3.8 MB/s eta 0:00:09
#    --------- ------------------------------ 9.4/38.8 MB 3.9 MB/s eta 0:00:08
#    ----------- ---------------------------- 10.7/38.8 MB 4.1 MB/s eta 0:00:07
#    ------------ --------------------------- 12.3/38.8 MB 4.4 MB/s eta 0:00:07
#    -------------- ------------------------- 13.6/38.8 MB 4.5 MB/s eta 0:00:06
#    --------------- ------------------------ 15.2/38.8 MB 4.7 MB/s eta 0:00:06
#    ---------------- ----------------------- 16.0/38.8 MB 4.6 MB/s eta 0:00:05
#    ----------------- ---------------------- 17.3/38.8 MB 4.7 MB/s eta 0:00:05
#    ------------------- -------------------- 18.6/38.8 MB 4.8 MB/s eta 0:00:05
#    -------------------- ------------------- 19.9/38.8 MB 4.9 MB/s eta 0:00:04
#    --------------------- ------------------ 21.2/38.8 MB 5.0 MB/s eta 0:00:04
#    ----------------------- ---------------- 22.8/38.8 MB 5.1 MB/s eta 0:00:04
#    ------------------------ --------------- 24.1/38.8 MB 5.1 MB/s eta 0:00:03
#    -------------------------- ------------- 25.4/38.8 MB 5.2 MB/s eta 0:00:03
#    --------------------------- ------------ 26.7/38.8 MB 5.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 28.0/38.8 MB 5.3 MB/s eta 0:00:03
#    ------------------------------ --------- 29.6/38.8 MB 5.4 MB/s eta 0:00:02
#    ------------------------------- -------- 30.9/38.8 MB 5.4 MB/s eta 0:00:02
#    --------------------------------- ------ 32.2/38.8 MB 5.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.6/38.8 MB 5.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.9/38.8 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------- -- 36.2/38.8 MB 5.5 MB/s eta 0:00:01
#    -------------------------------------- - 37.5/38.8 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.8 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 5.4 MB/s  0:00:07
# Downloading pi_heif-1.2.0-cp314-cp314-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    -------------------- ------------------- 1.0/2.0 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 5.4 MB/s  0:00:00
# Downloading pillow_avif_plugin-1.5.5-cp314-cp314-win_amd64.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/10.0 MB 5.3 MB/s eta 0:00:02
#    ------- -------------------------------- 1.8/10.0 MB 5.1 MB/s eta 0:00:02
#    ------------ --------------------------- 3.1/10.0 MB 5.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.2/10.0 MB 5.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.5/10.0 MB 5.4 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/10.0 MB 5.4 MB/s eta 0:00:01
#    ------------------------------- -------- 7.9/10.0 MB 5.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.9/10.0 MB 5.5 MB/s eta 0:00:01
#    -------------------------------------- - 9.7/10.0 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 5.3 MB/s  0:00:01
# Downloading tqdm-4.67.2-py3-none-any.whl (78 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: pillow-avif-plugin, filetype, tqdm, python-dotenv, pi-heif, opencv-python-headless, idna, requests-toolbelt, roboflow
#
#    ---------------------------------------- 0/9 [pillow-avif-plugin]
#    ---- ----------------------------------- 1/9 [filetype]
#    ---- ----------------------------------- 1/9 [filetype]
#    ---- ----------------------------------- 1/9 [filetype]
#    ---- ----------------------------------- 1/9 [filetype]
#    -------- ------------------------------- 2/9 [tqdm]
#    -------- ------------------------------- 2/9 [tqdm]
#    -------- ------------------------------- 2/9 [tqdm]
#    -------- ------------------------------- 2/9 [tqdm]
#    -------- ------------------------------- 2/9 [tqdm]
#    -------- ------------------------------- 2/9 [tqdm]
#    -------- ------------------------------- 2/9 [tqdm]
#    -------- ------------------------------- 2/9 [tqdm]
#    ------------- -------------------------- 3/9 [python-dotenv]
#    ------------- -------------------------- 3/9 [python-dotenv]
#    ------------- -------------------------- 3/9 [python-dotenv]
#    ----------------- ---------------------- 4/9 [pi-heif]
#    ----------------- ---------------------- 4/9 [pi-heif]
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#   Attempting uninstall: idna
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#     Found existing installation: idna 3.11
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#     Uninstalling idna-3.11:
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#       Successfully uninstalled idna-3.11
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#    -------------------------- ------------- 6/9 [idna]
#    -------------------------- ------------- 6/9 [idna]
#    -------------------------- ------------- 6/9 [idna]
#    ------------------------------- -------- 7/9 [requests-toolbelt]
#    ------------------------------- -------- 7/9 [requests-toolbelt]
#    ------------------------------- -------- 7/9 [requests-toolbelt]
#    ------------------------------- -------- 7/9 [requests-toolbelt]
#    ------------------------------- -------- 7/9 [requests-toolbelt]
#    ----------------------------------- ---- 8/9 [roboflow]
#    ----------------------------------- ---- 8/9 [roboflow]
#    ----------------------------------- ---- 8/9 [roboflow]
#    ----------------------------------- ---- 8/9 [roboflow]
#    ----------------------------------- ---- 8/9 [roboflow]
#    ----------------------------------- ---- 8/9 [roboflow]
#    ----------------------------------- ---- 8/9 [roboflow]
#    ----------------------------------- ---- 8/9 [roboflow]
#    ----------------------------------- ---- 8/9 [roboflow]
#    ---------------------------------------- 9/9 [roboflow]
#
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pi-heif-1.2.0 pillow-avif-plugin-1.5.5 python-dotenv-1.2.1 requests-toolbelt-1.0.0 roboflow-1.2.13 tqdm-4.67.2
#   WARNING: The script filetype.exe is installed in 'c:\Users\eya_k\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tqdm.exe is installed in 'c:\Users\eya_k\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script dotenv.exe is installed in 'c:\Users\eya_k\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script roboflow.exe is installed in 'c:\Users\eya_k\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="3M4msMXNUkQgPmq7X5cR")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-1 to yolov5pytorch:: 100%|██████████| 148663/148663 [00:24<00:00, 6023.49it/s]
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:04<00:00, 322.19it/s]

# %%
dataset.location
# Out:
# 'c:\\Users\\eya_k\\Desktop\\Football-analysis\\training\\football-players-detection-1'

# %% [markdown]
# Training

# %%
# !yolo  task=detect mode=train model=yolov5x.pt data={data.location}/data.yaml epochs=100 imgsz=640
