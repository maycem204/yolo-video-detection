# %% [markdown]
# <a href="https://colab.research.google.com/github/maycem204/yolo-video-detection/blob/main/football_training_yolo_v5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -m pip install python-dotenv

# %%
api_key ="3M4msMXNUkQgPmq7X5cR"
print("API key loaded:", api_key is not None)
# Out:
# API key loaded: True

# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("ROBOFLOW_API_KEY")

# %%
# !python -m pip install ultralytics
# !python -m pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 90.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 144.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.90
#     Uninstalling opencv-python-headless-4.13.0.90:
#       Successfully uninstalled opencv-python-headless-4.13.0.90
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %% [markdown]
# Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="3M4msMXNUkQgPmq7X5cR")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:00<00:00, 3131.94it/s]

# %%
dataset.location
# Out:
# '/content/football-players-detection-1'

# %%
# !cat /content/football-players-detection-1/data.yaml
# Out:
# names:
# - ball
# - goalkeeper
# - player
# - referee
# nc: 4
# roboflow:
#   license: CC BY 4.0
#   project: football-players-detection-3zvbc
#   url: https://universe.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc/dataset/1
#   version: 1
#   workspace: roboflow-jvuqo
# test: ../test/images
# train: football-players-detection-1/train/images
# val: football-players-detection-1/valid/images

# %% [markdown]
# Training

# %%
# !yolo  task=detect mode=train model=yolov5x.pt data=/content/football-players-detection-1/data.yaml epochs=100 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5x.pt' with new 'model=yolov5xu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Ultralytics 8.4.12 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
